# %% [markdown]
# # Imports

# %%
import math
from numpy import mgrid
import scipy.io as sio
import numpy as np
import cv2
from numpy import mgrid
import matplotlib.pyplot as plt

# %% [markdown]
# # Computer Exercise 4

# %%
#Load Data

mdict = sio.loadmat("./imgs_for_optical_flow.mat")
image1 = mdict["img1"]
image2 = mdict["img2"]
image3 = mdict["img3"]
image4 = mdict["img4"]
image5 = mdict["img5"]
image6 = mdict["img6"]

x = []
x.append(image1)
x.append(image2)
x.append(image3)
x.append(image4)
x.append(image5)
x.append(image6)
labes = ['original', 'opencv Remap', 'my interpolation']
fig, ax = plt.subplots(1, 6, figsize=(16, 6))

for i, Temp in enumerate(range(6)):
    t = ax[i].imshow(x[i], interpolation="None", vmin=-1, vmax=1, cmap="gray")
    ax[i].set_xticks([]), ax[i].set_yticks([])
    ax[i].set_title("Image " + str(i+1))

# fig.colorbar(t, ax=ax.ravel().tolist())
plt.show()

# %%
x = []
x.append(image2 - image1)
x.append(image3 - image1)
x.append(image4 - image1)
x.append(image5 - image1)
x.append(image6 - image1)

labes = ['original', 'opencv Remap', 'my interpolation']
fig, ax = plt.subplots(1, 5, figsize=(16, 6))

for i, Temp in enumerate(range(5)):
    t = ax[i].imshow(x[i], interpolation="None", vmin=-1, vmax=1, cmap="gray")
    ax[i].set_xticks([]), ax[i].set_yticks([])
    ax[i].set_title("Pair " + str(i+1))

# fig.colorbar(t, ax=ax.ravel().tolist())
plt.show()
